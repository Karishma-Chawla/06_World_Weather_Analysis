# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import requests
import time
from datetime import datetime
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
api_key=weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9e0813db451cb54ea1fcace0591cddb8&q=atar'

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tazovskiy
# Processing Record 2 of Set 1 | leningradskiy
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | chernyshevskiy
# Processing Record 5 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 1 | mosetse
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | sakakah
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | san patricio
# Processing Record 11 of Set 1 | buluang
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | rocha
# Processing Record 16 of Set 1 | kurumkan
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | kanniyakumari
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | itaituba
# Processing Record 30 of Set 1 | bontang
# Processing Record 31 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 1 | palana
# Processing Record 33 of Set 1 | kalengwa
# Processing Record 34 of Set 1 | komsomolskiy
# Processing Record 35 of Set 1 | kahului
# Processing Record 36 of Set 1 | abdulino
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | tazmalt
# Processing Record 39 of Set 1 | katsuura
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | san cristobal
# Processing Record 46 of Set 1 | visby
# Processing Record 47 of Set 1 | dwarka
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | bungu
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 2 | suining
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | pangnirtung
# Processing Record 8 of Set 2 | ginir
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | lerwick
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | hirna
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | coquimbo
# Processing Record 17 of Set 2 | novikovo
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | tandil
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | mahanoro
# Processing Record 23 of Set 2 | poum
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | twentynine palms
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | dauriya
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | codrington
# Processing Record 31 of Set 2 | carlos chagas
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | san andres
# Processing Record 34 of Set 2 | bentiu
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | finote selam
# Processing Record 38 of Set 2 | pacific grove
# Processing Record 39 of Set 2 | satipo
# Processing Record 40 of Set 2 | colares
# Processing Record 41 of Set 2 | baykit
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 2 | gamba
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | eureka
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | westport
# Processing Record 3 of Set 3 | qurbus
# Processing Record 4 of Set 3 | srednekolymsk
# Processing Record 5 of Set 3 | conceicao do araguaia
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | yulara
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | tacuarembo
# Processing Record 10 of Set 3 | batagay
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | bac lieu
# Processing Record 13 of Set 3 | tuatapere
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | rincon
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | terekli-mekteb
# Processing Record 19 of Set 3 | damphu
# Processing Record 20 of Set 3 | avarua
# Processing Record 21 of Set 3 | maraa
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | salalah
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | bemidji
# Processing Record 27 of Set 3 | izhma
# Processing Record 28 of Set 3 | peruibe
# Processing Record 29 of Set 3 | abonnema
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | reserva
# Processing Record 32 of Set 3 | taoudenni
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | maryville
# Processing Record 35 of Set 3 | nuristan
# Processing Record 36 of Set 3 | kendari
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | takoradi
# Processing Record 39 of Set 3 | san antonio
# Processing Record 40 of Set 3 | opuwo
# Processing Record 41 of Set 3 | porto nacional
# Processing Record 42 of Set 3 | mikkeli
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | ardistan
# City not found. Skipping...
# Processing Record 45 of Set 3 | bokoro
# Processing Record 46 of Set 3 | umm kaddadah
# Processing Record 47 of Set 3 | irbeyskoye
# Processing Record 48 of Set 3 | faya
# Processing Record 49 of Set 3 | san ramon
# Processing Record 50 of Set 3 | sitka
# Processing Record 1 of Set 4 | pevek
# Processing Record 2 of Set 4 | llandrindod wells
# Processing Record 3 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 4 | sigerfjord
# City not found. Skipping...
# Processing Record 5 of Set 4 | bairiki
# Processing Record 6 of Set 4 | ayr
# Processing Record 7 of Set 4 | yeniseysk
# Processing Record 8 of Set 4 | yanam
# Processing Record 9 of Set 4 | saldanha
# Processing Record 10 of Set 4 | qaanaaq
# Processing Record 11 of Set 4 | vanavara
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | mildura
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | bilma
# Processing Record 16 of Set 4 | balaguer
# Processing Record 17 of Set 4 | khandyga
# Processing Record 18 of Set 4 | emmett
# Processing Record 19 of Set 4 | remedios
# Processing Record 20 of Set 4 | aswan
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | kailua
# Processing Record 23 of Set 4 | coari
# Processing Record 24 of Set 4 | chuy
# Processing Record 25 of Set 4 | esna
# Processing Record 26 of Set 4 | santa cruz del sur
# Processing Record 27 of Set 4 | zabaykalsk
# Processing Record 28 of Set 4 | turayf
# Processing Record 29 of Set 4 | norman wells
# Processing Record 30 of Set 4 | kashi
# Processing Record 31 of Set 4 | rawson
# Processing Record 32 of Set 4 | gimli
# Processing Record 33 of Set 4 | nantucket
# Processing Record 34 of Set 4 | iquique
# Processing Record 35 of Set 4 | santa maria da boa vista
# Processing Record 36 of Set 4 | airai
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | port macquarie
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | kozani
# Processing Record 41 of Set 4 | abu ghosh
# Processing Record 42 of Set 4 | zaranj
# Processing Record 43 of Set 4 | vientiane
# Processing Record 44 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 4 | polis
# Processing Record 46 of Set 4 | beeville
# Processing Record 47 of Set 4 | padang
# Processing Record 48 of Set 4 | flinders
# Processing Record 49 of Set 4 | saint-michel-des-saints
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | kilosa
# Processing Record 3 of Set 5 | benin
# Processing Record 4 of Set 5 | iqaluit
# Processing Record 5 of Set 5 | haimen
# Processing Record 6 of Set 5 | lasem
# Processing Record 7 of Set 5 | luganville
# Processing Record 8 of Set 5 | dalbandin
# Processing Record 9 of Set 5 | san pedro
# Processing Record 10 of Set 5 | santa flavia
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | yenagoa
# Processing Record 13 of Set 5 | tongren
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | west bay
# Processing Record 16 of Set 5 | januaria
# Processing Record 17 of Set 5 | sabang
# Processing Record 18 of Set 5 | nikolskoye
# Processing Record 19 of Set 5 | jiaonan
# Processing Record 20 of Set 5 | joensuu
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | zarubino
# Processing Record 23 of Set 5 | gweta
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | gonaives
# Processing Record 26 of Set 5 | port hedland
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | kirakira
# Processing Record 29 of Set 5 | laurel
# Processing Record 30 of Set 5 | alandur
# Processing Record 31 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 5 | aykhal
# Processing Record 34 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 5 | fortuna
# Processing Record 36 of Set 5 | muncar
# Processing Record 37 of Set 5 | bandarbeyla
# Processing Record 38 of Set 5 | deep river
# Processing Record 39 of Set 5 | lianran
# Processing Record 40 of Set 5 | vardo
# Processing Record 41 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 5 | lavrentiya
# Processing Record 43 of Set 5 | ilhabela
# Processing Record 44 of Set 5 | tralee
# Processing Record 45 of Set 5 | walvis bay
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | kavieng
# Processing Record 48 of Set 5 | okulovka
# Processing Record 49 of Set 5 | maldonado
# Processing Record 50 of Set 5 | itarema
# Processing Record 1 of Set 6 | kannangad
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | olga
# Processing Record 5 of Set 6 | nemuro
# Processing Record 6 of Set 6 | humberto de campos
# Processing Record 7 of Set 6 | russell
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | mushie
# Processing Record 12 of Set 6 | teguldet
# Processing Record 13 of Set 6 | tiarei
# Processing Record 14 of Set 6 | rabat
# Processing Record 15 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 6 | longfeng
# Processing Record 19 of Set 6 | sovetskaya gavan
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | tynset
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | kauhajoki
# Processing Record 24 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 6 | salinas
# Processing Record 26 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 6 | smidovich
# Processing Record 28 of Set 6 | les cayes
# Processing Record 29 of Set 6 | bandarban
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | maragogi
# Processing Record 32 of Set 6 | carballo
# Processing Record 33 of Set 6 | saskylakh
# Processing Record 34 of Set 6 | parabel
# Processing Record 35 of Set 6 | lufilufi
# Processing Record 36 of Set 6 | lima
# Processing Record 37 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 6 | kawalu
# Processing Record 39 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 40 of Set 6 | waingapu
# Processing Record 41 of Set 6 | cherskiy
# Processing Record 42 of Set 6 | dikson
# Processing Record 43 of Set 6 | nioro
# Processing Record 44 of Set 6 | manaure
# Processing Record 45 of Set 6 | antsohihy
# Processing Record 46 of Set 6 | hami
# Processing Record 47 of Set 6 | contamana
# Processing Record 48 of Set 6 | alofi
# Processing Record 49 of Set 6 | rio grande
# Processing Record 50 of Set 6 | uribia
# Processing Record 1 of Set 7 | ilulissat
# Processing Record 2 of Set 7 | ust-koksa
# Processing Record 3 of Set 7 | zaysan
# Processing Record 4 of Set 7 | nome
# Processing Record 5 of Set 7 | conceicao da barra
# Processing Record 6 of Set 7 | sola
# Processing Record 7 of Set 7 | antofagasta
# Processing Record 8 of Set 7 | edd
# Processing Record 9 of Set 7 | camacha
# Processing Record 10 of Set 7 | am timan
# Processing Record 11 of Set 7 | berdigestyakh
# Processing Record 12 of Set 7 | nurota
# Processing Record 13 of Set 7 | ancud
# Processing Record 14 of Set 7 | usogorsk
# Processing Record 15 of Set 7 | sambava
# Processing Record 16 of Set 7 | iberia
# Processing Record 17 of Set 7 | at-bashi
# Processing Record 18 of Set 7 | zonguldak
# Processing Record 19 of Set 7 | uray
# Processing Record 20 of Set 7 | carlsbad
# Processing Record 21 of Set 7 | santana do paraiso
# Processing Record 22 of Set 7 | caucaia
# Processing Record 23 of Set 7 | la rioja
# Processing Record 24 of Set 7 | beipiao
# Processing Record 25 of Set 7 | camana
# Processing Record 26 of Set 7 | redmond
# Processing Record 27 of Set 7 | constantine
# Processing Record 28 of Set 7 | la baneza
# Processing Record 29 of Set 7 | rudnichnyy
# Processing Record 30 of Set 7 | lucapa
# Processing Record 31 of Set 7 | olinda
# Processing Record 32 of Set 7 | klyuchi
# Processing Record 33 of Set 7 | nouadhibou
# Processing Record 34 of Set 7 | sao pedro do sul
# Processing Record 35 of Set 7 | delta
# Processing Record 36 of Set 7 | orange walk
# Processing Record 37 of Set 7 | tomatlan
# Processing Record 38 of Set 7 | guerrero negro
# Processing Record 39 of Set 7 | kidal
# Processing Record 40 of Set 7 | freeport
# Processing Record 41 of Set 7 | cabra
# Processing Record 42 of Set 7 | tarhunah
# City not found. Skipping...
# Processing Record 43 of Set 7 | tabas
# Processing Record 44 of Set 7 | kaeo
# Processing Record 45 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 46 of Set 7 | santa rosa
# Processing Record 47 of Set 7 | meadow lake
# Processing Record 48 of Set 7 | ust-maya
# Processing Record 49 of Set 7 | sur
# Processing Record 50 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 8 | husavik
# Processing Record 2 of Set 8 | port lincoln
# Processing Record 3 of Set 8 | el rosario
# Processing Record 4 of Set 8 | abha
# Processing Record 5 of Set 8 | payo
# Processing Record 6 of Set 8 | nova olinda do norte
# Processing Record 7 of Set 8 | filadelfia
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | manvi
# Processing Record 10 of Set 8 | kerman
# Processing Record 11 of Set 8 | kahta
# Processing Record 12 of Set 8 | banjar
# Processing Record 13 of Set 8 | klaksvik
# Processing Record 14 of Set 8 | koungou
# Processing Record 15 of Set 8 | peremyshlyany
# Processing Record 16 of Set 8 | tamandare
# Processing Record 17 of Set 8 | trelew
# Processing Record 18 of Set 8 | loa janan
# Processing Record 19 of Set 8 | sao joao da barra
# Processing Record 20 of Set 8 | tocopilla
# Processing Record 21 of Set 8 | abaete
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | saint-leu
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | aksarka
# Processing Record 26 of Set 8 | chenghai
# Processing Record 27 of Set 8 | bowen
# Processing Record 28 of Set 8 | mega
# Processing Record 29 of Set 8 | beloha
# Processing Record 30 of Set 8 | berlevag
# Processing Record 31 of Set 8 | trinidad
# Processing Record 32 of Set 8 | saint george
# Processing Record 33 of Set 8 | peniche
# Processing Record 34 of Set 8 | ninghai
# Processing Record 35 of Set 8 | moron
# Processing Record 36 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 37 of Set 8 | canguaretama
# Processing Record 38 of Set 8 | komatipoort
# Processing Record 39 of Set 8 | bubaque
# Processing Record 40 of Set 8 | bethel
# Processing Record 41 of Set 8 | ulladulla
# Processing Record 42 of Set 8 | vila franca do campo
# Processing Record 43 of Set 8 | igarka
# Processing Record 44 of Set 8 | clarence town
# Processing Record 45 of Set 8 | duluth
# Processing Record 46 of Set 8 | leh
# Processing Record 47 of Set 8 | osorno
# Processing Record 48 of Set 8 | boyolangu
# Processing Record 49 of Set 8 | kazerun
# Processing Record 50 of Set 8 | itoman
# Processing Record 1 of Set 9 | beihai
# Processing Record 2 of Set 9 | sept-iles
# Processing Record 3 of Set 9 | marawi
# Processing Record 4 of Set 9 | asau
# Processing Record 5 of Set 9 | omsukchan
# Processing Record 6 of Set 9 | verkhnevilyuysk
# Processing Record 7 of Set 9 | dengzhou
# Processing Record 8 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 9 | malie
# Processing Record 10 of Set 9 | harlingen
# Processing Record 11 of Set 9 | mehamn
# Processing Record 12 of Set 9 | iquitos
# Processing Record 13 of Set 9 | balkhash
# Processing Record 14 of Set 9 | gornopravdinsk
# Processing Record 15 of Set 9 | matola
# Processing Record 16 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 9 | aktas
# Processing Record 18 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 19 of Set 9 | tongliao
# Processing Record 20 of Set 9 | marsala
# Processing Record 21 of Set 9 | nikko
# Processing Record 22 of Set 9 | homer
# Processing Record 23 of Set 9 | cabedelo
# Processing Record 24 of Set 9 | ixtapa
# Processing Record 25 of Set 9 | esso
# Processing Record 26 of Set 9 | torring
# Processing Record 27 of Set 9 | bonnyville
# Processing Record 28 of Set 9 | verkhoyansk
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | plettenberg bay
# Processing Record 31 of Set 9 | saint anthony
# Processing Record 32 of Set 9 | dingle
# Processing Record 33 of Set 9 | snezhnogorsk
# Processing Record 34 of Set 9 | perth
# Processing Record 35 of Set 9 | taua
# Processing Record 36 of Set 9 | mandla
# Processing Record 37 of Set 9 | amapa
# Processing Record 38 of Set 9 | dalvik
# Processing Record 39 of Set 9 | araouane
# Processing Record 40 of Set 9 | bengkulu
# Processing Record 41 of Set 9 | bontoc
# Processing Record 42 of Set 9 | mweka
# Processing Record 43 of Set 9 | papara
# Processing Record 44 of Set 9 | llanelli
# Processing Record 45 of Set 9 | muros
# Processing Record 46 of Set 9 | svetlogorsk
# Processing Record 47 of Set 9 | le vauclin
# Processing Record 48 of Set 9 | manzil jamil
# City not found. Skipping...
# Processing Record 49 of Set 9 | fort beaufort
# Processing Record 50 of Set 9 | viedma
# Processing Record 1 of Set 10 | lachute
# Processing Record 2 of Set 10 | adre
# Processing Record 3 of Set 10 | puerto asis
# Processing Record 4 of Set 10 | carutapera
# Processing Record 5 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 10 | voznesenye
# Processing Record 7 of Set 10 | sandnessjoen
# Processing Record 8 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 10 | namtsy
# Processing Record 10 of Set 10 | baiersbronn
# Processing Record 11 of Set 10 | mantua
# Processing Record 12 of Set 10 | cap malheureux
# Processing Record 13 of Set 10 | dhidhdhoo
# Processing Record 14 of Set 10 | esperance
# Processing Record 15 of Set 10 | ranong
# Processing Record 16 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 10 | porto novo
# Processing Record 18 of Set 10 | shahr-e babak
# Processing Record 19 of Set 10 | namatanai
# Processing Record 20 of Set 10 | egvekinot
# Processing Record 21 of Set 10 | sarab
# Processing Record 22 of Set 10 | mahon
# Processing Record 23 of Set 10 | belmonte
# Processing Record 24 of Set 10 | constitucion
# Processing Record 25 of Set 10 | college
# Processing Record 26 of Set 10 | traverse city
# Processing Record 27 of Set 10 | champerico
# Processing Record 28 of Set 10 | chicama
# Processing Record 29 of Set 10 | chapais
# Processing Record 30 of Set 10 | havoysund
# Processing Record 31 of Set 10 | thompson
# Processing Record 32 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | verkhnyaya inta
# Processing Record 34 of Set 10 | breaza
# Processing Record 35 of Set 10 | cidreira
# Processing Record 36 of Set 10 | erdenet
# Processing Record 37 of Set 10 | riyadh
# Processing Record 38 of Set 10 | sakaiminato
# Processing Record 39 of Set 10 | denia
# Processing Record 40 of Set 10 | yar-sale
# Processing Record 41 of Set 10 | oranjemund
# Processing Record 42 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 10 | ballinasloe
# Processing Record 44 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | pedernales
# Processing Record 47 of Set 10 | port blair
# Processing Record 48 of Set 10 | labuhan
# Processing Record 49 of Set 10 | saint andrews
# Processing Record 50 of Set 10 | umea
# Processing Record 1 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 11 | praia da vitoria
# Processing Record 3 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 11 | sulangan
# Processing Record 5 of Set 11 | linxia
# Processing Record 6 of Set 11 | petropavl
# Processing Record 7 of Set 11 | coos bay
# Processing Record 8 of Set 11 | santa marta
# Processing Record 9 of Set 11 | kimbe
# Processing Record 10 of Set 11 | sao jose da coroa grande
# Processing Record 11 of Set 11 | surt
# Processing Record 12 of Set 11 | santa cruz
# Processing Record 13 of Set 11 | rosendal
# Processing Record 14 of Set 11 | matamoros
# Processing Record 15 of Set 11 | san vicente
# Processing Record 16 of Set 11 | sergeyevka
# Processing Record 17 of Set 11 | olavarria
# Processing Record 18 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 11 | dunmore east
# Processing Record 20 of Set 11 | vestmannaeyjar
# Processing Record 21 of Set 11 | amahai
# Processing Record 22 of Set 11 | cape canaveral
# Processing Record 23 of Set 11 | pocoes
# Processing Record 24 of Set 11 | hasama
# City not found. Skipping...
# Processing Record 25 of Set 11 | safaga
# Processing Record 26 of Set 11 | santa isabel do rio negro
# Processing Record 27 of Set 11 | imeni poliny osipenko
# Processing Record 28 of Set 11 | fengcheng
# Processing Record 29 of Set 11 | ternate
# Processing Record 30 of Set 11 | ust-uda
# Processing Record 31 of Set 11 | bahia blanca
# Processing Record 32 of Set 11 | oconomowoc
# Processing Record 33 of Set 11 | bonfim
# Processing Record 34 of Set 11 | waipawa
# Processing Record 35 of Set 11 | jadu
# Processing Record 36 of Set 11 | naze
# Processing Record 37 of Set 11 | hay river
# Processing Record 38 of Set 11 | sorland
# Processing Record 39 of Set 11 | huarmey
# Processing Record 40 of Set 11 | la ronge
# Processing Record 41 of Set 11 | tongchuan
# Processing Record 42 of Set 11 | sao geraldo do araguaia
# Processing Record 43 of Set 11 | kudahuvadhoo
# Processing Record 44 of Set 11 | karratha
# Processing Record 45 of Set 11 | quedlinburg
# Processing Record 46 of Set 11 | albemarle
# Processing Record 47 of Set 11 | port lavaca
# Processing Record 48 of Set 11 | jimo
# Processing Record 49 of Set 11 | the valley
# Processing Record 50 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 12 | hibbing
# Processing Record 2 of Set 12 | sibolga
# Processing Record 3 of Set 12 | launceston
# Processing Record 4 of Set 12 | nambucca heads
# Processing Record 5 of Set 12 | srandakan
# Processing Record 6 of Set 12 | fukue
# Processing Record 7 of Set 12 | mayumba
# Processing Record 8 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 12 | ajdabiya
# Processing Record 10 of Set 12 | dharchula
# Processing Record 11 of Set 12 | olafsvik
# Processing Record 12 of Set 12 | san policarpo
# Processing Record 13 of Set 12 | alasehir
# Processing Record 14 of Set 12 | yakeshi
# Processing Record 15 of Set 12 | atoka
# Processing Record 16 of Set 12 | sayyan
# Processing Record 17 of Set 12 | manzanillo
# Processing Record 18 of Set 12 | nyurba
# Processing Record 19 of Set 12 | jumla
# Processing Record 20 of Set 12 | tiznit
# Processing Record 21 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 12 | algiers
# Processing Record 23 of Set 12 | andenes
# Processing Record 24 of Set 12 | wanning
# Processing Record 25 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 26 of Set 12 | mwinilunga
# Processing Record 27 of Set 12 | gavle
# Processing Record 28 of Set 12 | bosaso
# Processing Record 29 of Set 12 | barcelos
# Processing Record 30 of Set 12 | atar
# Processing Record 31 of Set 12 | aranos
# Processing Record 32 of Set 12 | patrocinio
# Processing Record 33 of Set 12 | cividale del friuli
# Processing Record 34 of Set 12 | toora-khem
# Processing Record 35 of Set 12 | dakar
# Processing Record 36 of Set 12 | havelock
# Processing Record 37 of Set 12 | marsa matruh
# Processing Record 38 of Set 12 | blagoyevo
# Processing Record 39 of Set 12 | umm lajj
# Processing Record 40 of Set 12 | altay
# Processing Record 41 of Set 12 | pitanga
# Processing Record 42 of Set 12 | dosso
# Processing Record 43 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 12 | ewa beach
# Processing Record 45 of Set 12 | necochea
# Processing Record 46 of Set 12 | revda
# Processing Record 47 of Set 12 | dali
# Processing Record 48 of Set 12 | oyek
# Processing Record 49 of Set 12 | ambad
# Processing Record 50 of Set 12 | hobyo
# Processing Record 1 of Set 13 | dogondoutchi
# Processing Record 2 of Set 13 | luderitz
# Processing Record 3 of Set 13 | san jose
# Processing Record 4 of Set 13 | iskenderun
# Processing Record 5 of Set 13 | mogadishu
# Processing Record 6 of Set 13 | quatre cocos
# Processing Record 7 of Set 13 | roald
# Processing Record 8 of Set 13 | boa vista
# Processing Record 9 of Set 13 | chandler
# Processing Record 10 of Set 13 | aqtobe
# Processing Record 11 of Set 13 | kavaratti
# Processing Record 12 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 13 of Set 13 | crossville
# Processing Record 14 of Set 13 | san lorenzo
# Processing Record 15 of Set 13 | kattivakkam
# Processing Record 16 of Set 13 | lumphat
# Processing Record 17 of Set 13 | bilibino
# Processing Record 18 of Set 13 | mende
# Processing Record 19 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 13 | carnduff
# Processing Record 21 of Set 13 | hecun
# Processing Record 22 of Set 13 | touros
# Processing Record 23 of Set 13 | hovd
# Processing Record 24 of Set 13 | ossora
# Processing Record 25 of Set 13 | tessalit
# Processing Record 26 of Set 13 | megion
# Processing Record 27 of Set 13 | beyneu
# Processing Record 28 of Set 13 | alihe
# Processing Record 29 of Set 13 | burica
# City not found. Skipping...
# Processing Record 30 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 31 of Set 13 | bodden town
# Processing Record 32 of Set 13 | nelson bay
# Processing Record 33 of Set 13 | thinadhoo
# Processing Record 34 of Set 13 | bulancak
# Processing Record 35 of Set 13 | koumac
# Processing Record 36 of Set 13 | orotukan
# Processing Record 37 of Set 13 | puri
# Processing Record 38 of Set 13 | blairgowrie
# Processing Record 39 of Set 13 | angoche
# Processing Record 40 of Set 13 | acarau
# Processing Record 41 of Set 13 | seymchan
# Processing Record 42 of Set 13 | mithimna
# City not found. Skipping...
# Processing Record 43 of Set 13 | saint-joseph
# Processing Record 44 of Set 13 | severnoye
# Processing Record 45 of Set 13 | dumbraveni
# Processing Record 46 of Set 13 | iracoubo
# Processing Record 47 of Set 13 | moussoro
# Processing Record 48 of Set 13 | galbshtadt
# Processing Record 49 of Set 13 | waw
# Processing Record 50 of Set 13 | labuan
# Processing Record 1 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | mwanza
# Processing Record 3 of Set 14 | filingue
# Processing Record 4 of Set 14 | yilan
# Processing Record 5 of Set 14 | chotila
# Processing Record 6 of Set 14 | gari
# Processing Record 7 of Set 14 | urucara
# Processing Record 8 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 14 | godeanu
# Processing Record 10 of Set 14 | souillac
# Processing Record 11 of Set 14 | altamont
# Processing Record 12 of Set 14 | chara
# Processing Record 13 of Set 14 | zyuzelskiy
# Processing Record 14 of Set 14 | anadyr
# Processing Record 15 of Set 14 | betsiamites
# Processing Record 16 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 14 | dovolnoye
# Processing Record 18 of Set 14 | abay
# Processing Record 19 of Set 14 | balykshi
# Processing Record 20 of Set 14 | poya
# Processing Record 21 of Set 14 | lakes entrance
# Processing Record 22 of Set 14 | manhattan
# Processing Record 23 of Set 14 | maceio
# Processing Record 24 of Set 14 | sfantu gheorghe
# Processing Record 25 of Set 14 | calabozo
# Processing Record 26 of Set 14 | henties bay
# Processing Record 27 of Set 14 | pulandian
# Processing Record 28 of Set 14 | broome
# Processing Record 29 of Set 14 | xaltianguis
# Processing Record 30 of Set 14 | nara
# Processing Record 31 of Set 14 | talaya
# Processing Record 32 of Set 14 | salta
# Processing Record 33 of Set 14 | manokwari
# Processing Record 34 of Set 14 | sao lourenco
# Processing Record 35 of Set 14 | luwuk
# Processing Record 36 of Set 14 | bhiwani
# Processing Record 37 of Set 14 | grand gaube
# Processing Record 38 of Set 14 | alice springs
# Processing Record 39 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 14 | farah
# Processing Record 41 of Set 14 | dunedin
# Processing Record 42 of Set 14 | antalaha
# Processing Record 43 of Set 14 | mount isa
# Processing Record 44 of Set 14 | sulam
# Processing Record 45 of Set 14 | auki
# Processing Record 46 of Set 14 | rundu
# Processing Record 47 of Set 14 | yatou
# Processing Record 48 of Set 14 | lebanon
# Processing Record 49 of Set 14 | bato
# Processing Record 50 of Set 14 | murray bridge
# Processing Record 1 of Set 15 | junin
# Processing Record 2 of Set 15 | porto walter
# Processing Record 3 of Set 15 | cairns
# Processing Record 4 of Set 15 | karaton
# Processing Record 5 of Set 15 | sistranda
# Processing Record 6 of Set 15 | zakharovo
# Processing Record 7 of Set 15 | kuhestan
# City not found. Skipping...
# Processing Record 8 of Set 15 | senno
# Processing Record 9 of Set 15 | northam
# Processing Record 10 of Set 15 | muroto
# Processing Record 11 of Set 15 | pandan
# Processing Record 12 of Set 15 | la tuque
# Processing Record 13 of Set 15 | yankton
# Processing Record 14 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 15 | yurla
# Processing Record 16 of Set 15 | malakal
# Processing Record 17 of Set 15 | qaqortoq
# Processing Record 18 of Set 15 | korla
# Processing Record 19 of Set 15 | santo antonio do ica
# Processing Record 20 of Set 15 | carnot
# Processing Record 21 of Set 15 | epe
# Processing Record 22 of Set 15 | okitipupa
# Processing Record 23 of Set 15 | quito
# Processing Record 24 of Set 15 | san quintin
# Processing Record 25 of Set 15 | mayo
# Processing Record 26 of Set 15 | san rafael
# Processing Record 27 of Set 15 | hervey bay
# Processing Record 28 of Set 15 | staryy nadym
# Processing Record 29 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 15 | mananjary
# Processing Record 31 of Set 15 | sobolevo
# Processing Record 32 of Set 15 | turukhansk
# Processing Record 33 of Set 15 | nuqui
# Processing Record 34 of Set 15 | maniitsoq
# Processing Record 35 of Set 15 | kpandae
# Processing Record 36 of Set 15 | sao francisco
# Processing Record 37 of Set 15 | tawkar
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tazovskiy  67.4667   78.7000      1.62        97         100
# 1   Leningradskiy  69.3833  178.4167     -5.91        97         100
# 2        Tasiilaq  65.6145  -37.6368     23.09        90         100
# 3  Chernyshevskiy  63.0128  112.4714     20.05        95         100
# 4         Mosetse -20.7500   26.6500     83.10        28          46
# 5       Upernavik  72.7868  -56.1549      7.18        88          92
# 6         Sakakah  29.9697   40.2064     83.77        18          76
# 7       Cape Town -33.9258   18.4232     63.27        63           0
# 8    San Patricio  28.0170  -97.5169     76.15        16           0
# 9         Buluang  13.3068  123.3425     74.62        94         100
#
#    Wind Speed Country Current Description
# 0        8.77      RU     overcast clouds
# 1       11.79      RU     overcast clouds
# 2        9.46      GL          light snow
# 3        8.59      RU     overcast clouds
# 4        5.44      BW    scattered clouds
# 5        3.29      GL     overcast clouds
# 6        6.11      SA       broken clouds
# 7       17.27      ZA           clear sky
# 8       16.84      US           clear sky
# 9        3.49      PH     overcast clouds

# %%
#city_data_df=city_data_df["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tazovskiy      RU  67.4667   78.7000      1.62        97         100
# 1   Leningradskiy      RU  69.3833  178.4167     -5.91        97         100
# 2        Tasiilaq      GL  65.6145  -37.6368     23.09        90         100
# 3  Chernyshevskiy      RU  63.0128  112.4714     20.05        95         100
# 4         Mosetse      BW -20.7500   26.6500     83.10        28          46
#
#    Wind Speed Current Description
# 0        8.77     overcast clouds
# 1       11.79     overcast clouds
# 2        9.46          light snow
# 3        8.59     overcast clouds
# 4        5.44    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
